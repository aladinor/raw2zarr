# %%
import xarray as xr
from xarray.backends.api import open_datatree

# %%
xr.__version__
# Out:
# '2024.9.1.dev23+g52f13d44'

# %%
path = "/media/alfonso/drive/Alfonso/python/raw2zarr/zarr/Guaviare_V2.zarr"

# %%
# %%time
dt = open_datatree(path, engine="zarr", consolidated="True", chunks={})
# Out:
# CPU times: user 3.95 s, sys: 654 ms, total: 4.61 s
# Wall time: 5.99 s

# %%
print(f"size in GB {dt.nbytes / 1024**3}")
# Out:
# size in GB 105.6224237754941

# %%
dt["sweep_0"].to_dataset().vcp_time  # .sel(vcp_time="2022-06-01")
# Out:
# <xarray.DataArray 'vcp_time' (vcp_time: 847)> Size: 7kB
# array(['2022-06-01T00:00:11.780999936', '2022-06-01T00:05:21.983000064',
#        '2022-06-01T00:10:31.363000064', ..., '2022-06-04T23:35:11.759000064',
#        '2022-06-04T23:40:16.840999936', '2022-06-04T23:45:33.212000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     altitude   float64 8B ...
#     crs_wkt    int64 8B ...
#     latitude   float64 8B ...
#     longitude  float64 8B ...
#   * vcp_time   (vcp_time) datetime64[ns] 7kB 2022-06-01T00:00:11.780999936 .....
